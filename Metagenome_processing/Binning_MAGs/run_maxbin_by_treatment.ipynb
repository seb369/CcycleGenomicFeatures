# %% [markdown]
# # Running MaxBin to make bins within each treatment

# %%
import os
import pandas as pd
from Bio import SeqIO

# %%
baseDir = '/home/sam/FullCyc_metagenome/enriched_binning'
enr_contigs = '/home/sam/FullCyc_metagenome/enriched_binning/enriched_contigs_per_treatment.txt'
alignDir = '/home/sam/FullCyc_metagenome/alignments_1000k'

ncores = 10

# %%
treatments = list(set(pd.read_csv(enr_contigs, sep='\t')['Treatment']))
treatments
# Out:
# ['Xylose_Day06',
#  'Vanillin_Day48',
#  'PalmiticAcid_Day48',
#  'PalmiticAcid_Day30',
#  'Cellulose_Day30',
#  'Glucose_Day01',
#  'Glucose_Day14',
#  'Glycerol_Day14']

# %% [markdown]
# ### Getting abundance tables
#
# Take the abundance tables from MetaBAT

# %%
contigs_by_treat = pd.read_csv(enr_contigs, sep='\t')

for treat in treatments:
    print('Running:   ' + treat)
    workDir = os.path.join(baseDir, treat)
    day = int(treat.split('_Day')[1])
    substrate = treat.split('_Day')[0]
    full_cov_df = pd.read_csv(os.path.join(workDir, 'full_metabat_depths.txt'), sep='\t')
    full_cov_df = full_cov_df[full_cov_df.contigName.isin(contigs_by_treat[contigs_by_treat['Treatment'] == treat]['contigName'])]
    treat_cov_df = full_cov_df[['contigName', '_'.join([substrate, 'Day'+str(day), 'mapped.sorted.bam'])]]
    treat_cov_df.to_csv(os.path.join(workDir, treat+'_maxbin_depths.txt'), sep='\t', header=False, index=False)
    con_cov_df = full_cov_df[['contigName', '_'.join(['Control', 'Day'+str(day), 'mapped.sorted.bam'])]]
    con_cov_df.to_csv(os.path.join(workDir, treat.replace(substrate, 'Control')+'_maxbin_depths.txt'), sep='\t', header=False, index=False)
    full_cov_df = None
    treat_cov_df = None
    con_cov_df = None
    
contigs_by_treat = None
# Out:
# Running:   Xylose_Day06
# Running:   Vanillin_Day48
# Running:   PalmiticAcid_Day48
# Running:   PalmiticAcid_Day30
# Running:   Cellulose_Day30
# Running:   Glucose_Day01
# Running:   Glucose_Day14
# Running:   Glycerol_Day14

# %% [markdown]
# ### Run MaxBin2

# %%
for treat in treatments:
    print('Running:   ' + treat)
    substrate = treat.split('_Day')[0]
    workDir = os.path.join(baseDir, treat)
    outDir = os.path.join(workDir, treat + '_maxbin_binning')
    os.makedirs(outDir)
    cmd = ' '.join(['run_MaxBin.pl',
                    '-contig', os.path.join(workDir, treat+'.enr.contigs.1000.fasta'),
                    '-abund', os.path.join(workDir, treat+'_maxbin_depths.txt'),
                    '-abund2', os.path.join(workDir, treat.replace(substrate, 'Control')+'_maxbin_depths.txt'),
                    '-min_contig_length 1000',
                    '-thread', str(ncores),
                    '-out', os.path.join(outDir, treat+'_maxbin_out')])
    # !$cmd              
    print('\n-----\n\n')
# Out:
# Running:   Xylose_Day06
# readline() on closed filehandle FILE at /home/sam/anaconda3/envs/metawrap-env/bin/run_MaxBin.pl line 1336.
# MaxBin 2.2.4
# Input contig: /home/sam/FullCyc_metagenome/enriched_binning/Xylose_Day06/Xylose_Day06.enr.contigs.1000.fasta
# Located abundance file [/home/sam/FullCyc_metagenome/enriched_binning/Xylose_Day06/Xylose_Day06_maxbin_depths.txt]
# Located abundance file [/home/sam/FullCyc_metagenome/enriched_binning/Xylose_Day06/Control_Day06_maxbin_depths.txt]
# Min contig length: 1000
# Thread: 10
# out header: /home/sam/FullCyc_metagenome/enriched_binning/Xylose_Day06/Xylose_Day06_maxbin_binning/Xylose_Day06_maxbin_out
# Searching against 107 marker genes to find starting seed contigs for [/home/sam/FullCyc_metagenome/enriched_binning/Xylose_Day06/Xylose_Day06.enr.contigs.1000.fasta]...
# Running FragGeneScan....
# Running HMMER hmmsearch....
# Done data collection. Running MaxBin...
# Command: /home/sam/anaconda3/envs/metawrap-env/bin/src/MaxBin -fasta /home/sam/FullCyc_metagenome/enriched_binning/Xylose_Day06/Xylose_Day06_maxbin_binning/Xylose_Day06_maxbin_out.contig.tmp  -abund /home/sam/FullCyc_metagenome/enriched_binning/Xylose_Day06/Xylose_Day06_maxbin_binning/Xylose_Day06_maxbin_out.contig.tmp.abund1 -abund2 /home/sam/FullCyc_metagenome/enriched_binning/Xylose_Day06/Xylose_Day06_maxbin_binning/Xylose_Day06_maxbin_out.contig.tmp.abund2 -seed /home/sam/FullCyc_metagenome/enriched_binning/Xylose_Day06/Xylose_Day06_maxbin_binning/Xylose_Day06_maxbin_out.seed -out /home/sam/FullCyc_metagenome/enriched_binning/Xylose_Day06/Xylose_Day06_maxbin_binning/Xylose_Day06_maxbin_out -min_contig_length 1000 -thread 10
# Minimum contig length set to 1000.
# Reading seed list...
# Looking for seeds in sequences.
# 	scaffold_172635_c1 [85.080400] [37.695500]
# 	scaffold_387037_c1 [81.705900] [36.820100]
# 	scaffold_109613_c2 [20.733400] [7.113160]
# 	scaffold_1188821_c1 [8.897350] [2.644750]
# 	scaffold_1203093_c1 [59.989600] [3.712300]
# Get 5 seeds.
#
# Start EM process.
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Iteration 6
# Iteration 7
# Iteration 8
# Iteration 9
# Iteration 10
# Iteration 11
# Iteration 12
# Iteration 13
# Iteration 14
# Iteration 15
# Iteration 16
# Iteration 17
# Iteration 18
# Iteration 19
# Iteration 20
# Iteration 21
# Iteration 22
# Iteration 23
# Iteration 24
# Iteration 25
# Iteration 26
# Iteration 27
# Iteration 28
# Iteration 29
# Iteration 30
# Iteration 31
# Iteration 32
# Iteration 33
# Iteration 34
# Iteration 35
# Iteration 36
# Iteration 37
# Iteration 38
# Iteration 39
# Iteration 40
# Iteration 41
# Iteration 42
# Iteration 43
# Iteration 44
# Iteration 45
# Iteration 46
# Iteration 47
#
# EM finishes successfully.
#
# Classifying sequences based on the EM result.
# Minimum probability for binning: 0.50
# Ignoring 0 bins without any sequences.
# Number of unclassified sequences: 3 (0.01%)
# Elapsed time:  0 days 00:03:19
# Done data collection. Running MaxBin...
# Command: /home/sam/anaconda3/envs/metawrap-env/bin/src/MaxBin -fasta /home/sam/FullCyc_metagenome/enriched_binning/Xylose_Day06/Xylose_Day06_maxbin_binning/Xylose_Day06_maxbin_out.0002.fasta  -abund /home/sam/FullCyc_metagenome/enriched_binning/Xylose_Day06/Xylose_Day06_maxbin_binning/Xylose_Day06_maxbin_out.contig.tmp.abund1 -abund2 /home/sam/FullCyc_metagenome/enriched_binning/Xylose_Day06/Xylose_Day06_maxbin_binning/Xylose_Day06_maxbin_out.contig.tmp.abund2 -seed /home/sam/FullCyc_metagenome/enriched_binning/Xylose_Day06/Xylose_Day06_maxbin_binning/Xylose_Day06_maxbin_out.0002.out.seed -out /home/sam/FullCyc_metagenome/enriched_binning/Xylose_Day06/Xylose_Day06_maxbin_binning/Xylose_Day06_maxbin_out.0002.out -min_contig_length 1000 -thread 10
# Minimum contig length set to 1000.
# Reading seed list...
# Looking for seeds in sequences.
# 	scaffold_172635_c1 [85.080400] [37.695500]
# 	scaffold_387037_c1 [81.705900] [36.820100]
# Get 2 seeds.
#
# Start EM process.
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Iteration 6
# Iteration 7
# Iteration 8
# Iteration 9
# Iteration 10
# Iteration 11
# Iteration 12
# Iteration 13
# Iteration 14
#
# EM finishes successfully.
#
# Classifying sequences based on the EM result.
# Minimum probability for binning: 0.50
# Ignoring 0 bins without any sequences.
# Number of unclassified sequences: 0 (0.00%)
# Elapsed time:  0 days 00:00:04
# Done data collection. Running MaxBin...
# Command: /home/sam/anaconda3/envs/metawrap-env/bin/src/MaxBin -fasta /home/sam/FullCyc_metagenome/enriched_binning/Xylose_Day06/Xylose_Day06_maxbin_binning/Xylose_Day06_maxbin_out.0004.fasta  -abund /home/sam/FullCyc_metagenome/enriched_binning/Xylose_Day06/Xylose_Day06_maxbin_binning/Xylose_Day06_maxbin_out.contig.tmp.abund1 -abund2 /home/sam/FullCyc_metagenome/enriched_binning/Xylose_Day06/Xylose_Day06_maxbin_binning/Xylose_Day06_maxbin_out.contig.tmp.abund2 -seed /home/sam/FullCyc_metagenome/enriched_binning/Xylose_Day06/Xylose_Day06_maxbin_binning/Xylose_Day06_maxbin_out.0004.out.seed -out /home/sam/FullCyc_metagenome/enriched_binning/Xylose_Day06/Xylose_Day06_maxbin_binning/Xylose_Day06_maxbin_out.0004.out -min_contig_length 1000 -thread 10
# Minimum contig length set to 1000.
# Reading seed list...
# Looking for seeds in sequences.
# 	scaffold_206367_c1 [19.855700] [3.678000]
# 	scaffold_378513_c1 [11.198000] [0.742574]
# 	scaffold_627209_c1 [10.414200] [0.656743]
# 	scaffold_724682_c1 [17.457600] [5.386770]
# Get 4 seeds.
#
# Start EM process.
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Iteration 6
# Iteration 7
# Iteration 8
# Iteration 9
# Iteration 10
# Iteration 11
# Iteration 12
# Iteration 13
# Iteration 14
# Iteration 15
# Iteration 16
# Iteration 17
# Iteration 18
# Iteration 19
# Iteration 20
# Iteration 21
# Iteration 22
# Iteration 23
# Iteration 24
# Iteration 25
# Iteration 26
# Iteration 27
# Iteration 28
# Iteration 29
# Iteration 30
# Iteration 31
# Iteration 32
# Iteration 33
# Iteration 34
# Iteration 35
# Iteration 36
# Iteration 37
# Iteration 38
# Iteration 39
# Iteration 40
# Iteration 41
# Iteration 42
# Iteration 43
# Iteration 44
# Iteration 45
# Iteration 46
# Iteration 47
# Iteration 48
# Iteration 49
# Iteration 50
#
# EM finishes successfully.
#
# Classifying sequences based on the EM result.
# Minimum probability for binning: 0.50
# Ignoring 0 bins without any sequences.
# Number of unclassified sequences: 621 (1.74%)
# Elapsed time:  0 days 00:02:20
# Done data collection. Running MaxBin...
# Command: /home/sam/anaconda3/envs/metawrap-env/bin/src/MaxBin -fasta /home/sam/FullCyc_metagenome/enriched_binning/Xylose_Day06/Xylose_Day06_maxbin_binning/Xylose_Day06_maxbin_out.0004.out.0004.fasta  -abund /home/sam/FullCyc_metagenome/enriched_binning/Xylose_Day06/Xylose_Day06_maxbin_binning/Xylose_Day06_maxbin_out.contig.tmp.abund1 -abund2 /home/sam/FullCyc_metagenome/enriched_binning/Xylose_Day06/Xylose_Day06_maxbin_binning/Xylose_Day06_maxbin_out.contig.tmp.abund2 -seed /home/sam/FullCyc_metagenome/enriched_binning/Xylose_Day06/Xylose_Day06_maxbin_binning/Xylose_Day06_maxbin_out.0004.out.0004.out.seed -out /home/sam/FullCyc_metagenome/enriched_binning/Xylose_Day06/Xylose_Day06_maxbin_binning/Xylose_Day06_maxbin_out.0004.out.0004.out -min_contig_length 1000 -thread 10
# Minimum contig length set to 1000.
# Reading seed list...
# Looking for seeds in sequences.
# 	scaffold_109613_c2 [20.733400] [7.113160]
# 	scaffold_1188821_c1 [8.897350] [2.644750]
# Get 2 seeds.
#
# Start EM process.
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Iteration 6
# Iteration 7
# Iteration 8
# Iteration 9
# Iteration 10
# Iteration 11
# Iteration 12
# Iteration 13
# Iteration 14
# Iteration 15
# Iteration 16
# Iteration 17
# Iteration 18
# Iteration 19
# Iteration 20
# Iteration 21
# Iteration 22
# Iteration 23
# Iteration 24
# Iteration 25
# Iteration 26
# Iteration 27
# Iteration 28
# Iteration 29
# Iteration 30
# Iteration 31
# Iteration 32
# Iteration 33
# Iteration 34
# Iteration 35
# Iteration 36
# Iteration 37
# Iteration 38
# Iteration 39
# Iteration 40
# Iteration 41
# Iteration 42
# Iteration 43
# Iteration 44
# Iteration 45
# Iteration 46
# Iteration 47
# Iteration 48
# Iteration 49
# Iteration 50
#
# EM finishes successfully.
#
# Classifying sequences based on the EM result.
# Minimum probability for binning: 0.50
# Ignoring 0 bins without any sequences.
# Number of unclassified sequences: 0 (0.00%)
# Elapsed time:  0 days 00:00:31
# Minimum contig length set to 1000.
# Reading seed list...
# Looking for seeds in sequences.
# 	scaffold_172635_c1 [85.080400] [37.695500]
# 	scaffold_387037_c1 [81.705900] [36.820100]
# 	scaffold_109613_c2 [20.733400] [7.113160]
# 	scaffold_1188821_c1 [8.897350] [2.644750]
# 	scaffold_1203093_c1 [59.989600] [3.712300]
# Get 5 seeds.
#
# Start EM process.
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Iteration 6
# Iteration 7
# Iteration 8
# Iteration 9
# Iteration 10
# Iteration 11
# Iteration 12
# Iteration 13
# Iteration 14
# Iteration 15
# Iteration 16
# Iteration 17
# Iteration 18
# Iteration 19
# Iteration 20
# Iteration 21
# Iteration 22
# Iteration 23
# Iteration 24
# Iteration 25
# Iteration 26
# Iteration 27
# Iteration 28
# Iteration 29
# Iteration 30
# Iteration 31
# Iteration 32
# Iteration 33
# Iteration 34
# Iteration 35
# Iteration 36
# Iteration 37
# Iteration 38
# Iteration 39
# Iteration 40
# Iteration 41
# Iteration 42
# Iteration 43
# Iteration 44
# Iteration 45
# Iteration 46
# Iteration 47
#
# EM finishes successfully.
#
# Classifying sequences based on the EM result.
# Minimum probability for binning: 0.50
# Ignoring 0 bins without any sequences.
# Number of unclassified sequences: 3 (0.01%)
# Elapsed time:  0 days 00:03:19
#
# Minimum contig length set to 1000.
# Reading seed list...
# Looking for seeds in sequences.
# 	scaffold_172635_c1 [85.080400] [37.695500]
# 	scaffold_387037_c1 [81.705900] [36.820100]
# Get 2 seeds.
#
# Start EM process.
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Iteration 6
# Iteration 7
# Iteration 8
# Iteration 9
# Iteration 10
# Iteration 11
# Iteration 12
# Iteration 13
# Iteration 14
#
# EM finishes successfully.
#
# Classifying sequences based on the EM result.
# Minimum probability for binning: 0.50
# Ignoring 0 bins without any sequences.
# Number of unclassified sequences: 0 (0.00%)
# Elapsed time:  0 days 00:00:04
#
# Minimum contig length set to 1000.
# Reading seed list...
# Looking for seeds in sequences.
# 	scaffold_206367_c1 [19.855700] [3.678000]
# 	scaffold_378513_c1 [11.198000] [0.742574]
# 	scaffold_627209_c1 [10.414200] [0.656743]
# 	scaffold_724682_c1 [17.457600] [5.386770]
# Get 4 seeds.
#
# Start EM process.
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Iteration 6
# Iteration 7
# Iteration 8
# Iteration 9
# Iteration 10
# Iteration 11
# Iteration 12
# Iteration 13
# Iteration 14
# Iteration 15
# Iteration 16
# Iteration 17
# Iteration 18
# Iteration 19
# Iteration 20
# Iteration 21
# Iteration 22
# Iteration 23
# Iteration 24
# Iteration 25
# Iteration 26
# Iteration 27
# Iteration 28
# Iteration 29
# Iteration 30
# Iteration 31
# Iteration 32
# Iteration 33
# Iteration 34
# Iteration 35
# Iteration 36
# Iteration 37
# Iteration 38
# Iteration 39
# Iteration 40
# Iteration 41
# Iteration 42
# Iteration 43
# Iteration 44
# Iteration 45
# Iteration 46
# Iteration 47
# Iteration 48
# Iteration 49
# Iteration 50
#
# EM finishes successfully.
#
# Classifying sequences based on the EM result.
# Minimum probability for binning: 0.50
# Ignoring 0 bins without any sequences.
# Number of unclassified sequences: 621 (1.74%)
# Elapsed time:  0 days 00:02:20
#
# Minimum contig length set to 1000.
# Reading seed list...
# Looking for seeds in sequences.
# 	scaffold_109613_c2 [20.733400] [7.113160]
# 	scaffold_1188821_c1 [8.897350] [2.644750]
# Get 2 seeds.
#
# Start EM process.
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Iteration 6
# Iteration 7
# Iteration 8
# Iteration 9
# Iteration 10
# Iteration 11
# Iteration 12
# Iteration 13
# Iteration 14
# Iteration 15
# Iteration 16
# Iteration 17
# Iteration 18
# Iteration 19
# Iteration 20
# Iteration 21
# Iteration 22
# Iteration 23
# Iteration 24
# Iteration 25
# Iteration 26
# Iteration 27
# Iteration 28
# Iteration 29
# Iteration 30
# Iteration 31
# Iteration 32
# Iteration 33
# Iteration 34
# Iteration 35
# Iteration 36
# Iteration 37
# Iteration 38
# Iteration 39
# Iteration 40
# Iteration 41
# Iteration 42
# Iteration 43
# Iteration 44
# Iteration 45
# Iteration 46
# Iteration 47
# Iteration 48
# Iteration 49
# Iteration 50
#
# EM finishes successfully.
#
# Classifying sequences based on the EM result.
# Minimum probability for binning: 0.50
# Ignoring 0 bins without any sequences.
# Number of unclassified sequences: 0 (0.00%)
# Elapsed time:  0 days 00:00:31
# Xylose_Day06_maxbin_out.001.marker.fasta
# Xylose_Day06_maxbin_out.002.marker.fasta
# Xylose_Day06_maxbin_out.003.marker.fasta
# Xylose_Day06_maxbin_out.004.marker.fasta
# Xylose_Day06_maxbin_out.005.marker.fasta
# Xylose_Day06_maxbin_out.006.marker.fasta
# Xylose_Day06_maxbin_out.007.marker.fasta
# Xylose_Day06_maxbin_out.008.marker.fasta
# Xylose_Day06_maxbin_out.009.marker.fasta
# Xylose_Day06_maxbin_out.010.marker.fasta
# Deleting intermediate files.
#
#
# ========== Job finished ==========
# Yielded 10 bins for contig (scaffold) file /home/sam/FullCyc_metagenome/enriched_binning/Xylose_Day06/Xylose_Day06.enr.contigs.1000.fasta
#
# Here are the output files for this run.
# Please refer to the README file for further details.
#
# Summary file: /home/sam/FullCyc_metagenome/enriched_binning/Xylose_Day06/Xylose_Day06_maxbin_binning/Xylose_Day06_maxbin_out.summary
# Genome abundance info file: /home/sam/FullCyc_metagenome/enriched_binning/Xylose_Day06/Xylose_Day06_maxbin_binning/Xylose_Day06_maxbin_out.abundance
# Marker counts: /home/sam/FullCyc_metagenome/enriched_binning/Xylose_Day06/Xylose_Day06_maxbin_binning/Xylose_Day06_maxbin_out.marker
# Marker genes for each bin: /home/sam/FullCyc_metagenome/enriched_binning/Xylose_Day06/Xylose_Day06_maxbin_binning/Xylose_Day06_maxbin_out.marker_of_each_gene.tar.gz
# Bin files: /home/sam/FullCyc_metagenome/enriched_binning/Xylose_Day06/Xylose_Day06_maxbin_binning/Xylose_Day06_maxbin_out.001.fasta - /home/sam/FullCyc_metagenome/enriched_binning/Xylose_Day06/Xylose_Day06_maxbin_binning/Xylose_Day06_maxbin_out.010.fasta
# Unbinned sequences: /home/sam/FullCyc_metagenome/enriched_binning/Xylose_Day06/Xylose_Day06_maxbin_binning/Xylose_Day06_maxbin_out.noclass
#
#
# ========== Elapsed Time ==========
# 0 hours 7 minutes and 6 seconds.
#
#
# -----
#
#
# Running:   Vanillin_Day48
# readline() on closed filehandle FILE at /home/sam/anaconda3/envs/metawrap-env/bin/run_MaxBin.pl line 1336.
# MaxBin 2.2.4
# Input contig: /home/sam/FullCyc_metagenome/enriched_binning/Vanillin_Day48/Vanillin_Day48.enr.contigs.1000.fasta
# Located abundance file [/home/sam/FullCyc_metagenome/enriched_binning/Vanillin_Day48/Vanillin_Day48_maxbin_depths.txt]
# Located abundance file [/home/sam/FullCyc_metagenome/enriched_binning/Vanillin_Day48/Control_Day48_maxbin_depths.txt]
# Min contig length: 1000
# Thread: 10
# out header: /home/sam/FullCyc_metagenome/enriched_binning/Vanillin_Day48/Vanillin_Day48_maxbin_binning/Vanillin_Day48_maxbin_out
# Searching against 107 marker genes to find starting seed contigs for [/home/sam/FullCyc_metagenome/enriched_binning/Vanillin_Day48/Vanillin_Day48.enr.contigs.1000.fasta]...
# Running FragGeneScan....
# Running HMMER hmmsearch....
# Done data collection. Running MaxBin...
# Command: /home/sam/anaconda3/envs/metawrap-env/bin/src/MaxBin -fasta /home/sam/FullCyc_metagenome/enriched_binning/Vanillin_Day48/Vanillin_Day48_maxbin_binning/Vanillin_Day48_maxbin_out.contig.tmp  -abund /home/sam/FullCyc_metagenome/enriched_binning/Vanillin_Day48/Vanillin_Day48_maxbin_binning/Vanillin_Day48_maxbin_out.contig.tmp.abund1 -abund2 /home/sam/FullCyc_metagenome/enriched_binning/Vanillin_Day48/Vanillin_Day48_maxbin_binning/Vanillin_Day48_maxbin_out.contig.tmp.abund2 -seed /home/sam/FullCyc_metagenome/enriched_binning/Vanillin_Day48/Vanillin_Day48_maxbin_binning/Vanillin_Day48_maxbin_out.seed -out /home/sam/FullCyc_metagenome/enriched_binning/Vanillin_Day48/Vanillin_Day48_maxbin_binning/Vanillin_Day48_maxbin_out -min_contig_length 1000 -thread 10
# Loaded 100000 sequences
# Minimum contig length set to 1000.
# Reading seed list...
# Looking for seeds in sequences.
# 	scaffold_16666_c1 [68.637200] [4.562820]
# 	scaffold_26271_c1 [87.457600] [37.105500]
# 	scaffold_86314_c1 [36.479800] [23.947700]
# 	scaffold_126856_c1 [53.833300] [37.184200]
# 	scaffold_216087_c1 [439.431000] [32.709900]
# 	scaffold_325473_c1 [91.853300] [5.865210]
# 	scaffold_178607_c1 [49.776700] [74.971200]
# 	scaffold_379177_c1 [28.961100] [1.991510]
# 	scaffold_545307_c1 [22.492600] [17.889400]
# 	scaffold_616025_c1 [119.011000] [28.954800]
# 	scaffold_680768_c1 [13.473700] [4.430130]
# 	scaffold_685096_c1 [9.396720] [10.020000]
# 	scaffold_821715_c1 [11.496100] [6.366140]
# 	scaffold_852251_c1 [9.985010] [6.801200]
# 	scaffold_959379_c1 [17.233400] [6.041010]
# 	scaffold_1076658_c1 [23.408800] [1.922650]
# 	scaffold_1094409_c1 [5.651450] [6.483300]
# Get 17 seeds.
#
# Start EM process.
# Iteration 1
# Iteration 2
# Iteration 3
# Iteration 4
# Iteration 5
# Iteration 6
# Iteration 7
# Iteration 8
# Iteration 9
# Iteration 10
# Iteration 11
# Iteration 12
# Iteration 13
# Iteration 14
# Iteration 15
# Iteration 16
# Iteration 17
# Iteration 18
# Iteration 19
# Iteration 20
# Iteration 21
# Iteration 22
# Iteration 23
# Iteration 24
# Iteration 25
# Iteration 26
# Iteration 27
# Iteration 28
# Iteration 29
# Iteration 30

# %% [markdown]
# ### Make bin summary file

# %%
for treat in treatments:
    print('Running:   ' + treat)
    workDir = os.path.join(baseDir, treat, treat + '_maxbin_binning')
    binfiles = [f for f in os.listdir(workDir) if f.startswith(treat+'_maxbin_out') and f.endswith('fasta')]
    with open(os.path.join(workDir, treat + '_maxbin_bin_assignments.txt'), 'w') as outfile:
        outfile.write('contigName\tbin\n')
        for binfasta in binfiles:
            bin_number = int(binfasta.replace(treat+'_maxbin_out.', '').replace('.fasta', ''))
            for record in SeqIO.parse(os.path.join(workDir, binfasta), 'fasta'):
                outfile.write(record.id + '\t' + str(bin_number) + '\n')
    print('\n-----\n\n')
